# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import sys
import re
import math
import numpy 
import pandas as pd   
import xlwt 
import random
import os
import urllib.request
import urllib


chrome_path = 'C:\\crawling\\chromedriver_win32\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)

url = 'https://www.coupang.com/'
driver.get(url)

num = input("""크롤링 하려는 항목 번호를 입력해주세요
1.여성패션    2.남성패션        3.뷰티          4.출산.육아등    5.식품
6.주방용품    7.생활용품        8.홈인테리어    9.가전디지털    10.스포츠/레저
11.자동차용품 12.도서/음반/DVD 13.완구/취미     14.문구/오피스 15.반려동물용품 16.헬스건강식품
""")

driver.delete_all_cookies()
time.sleep(2)



if num == '1' :
    num_name='패션의류_잡화-남성'
elif num =='2' :
    num_name='패션의류_잡화-여성'
elif num =='3' :
    num_name='뷰티'
elif num =='4' :
    num_name='출산_유아동'
elif num =='5' :
    num_name='식품'
elif num =='6' :
    num_name='주방용품'
elif num =='7' :
    num_name='생활용품'
elif num =='8' :
    num_name='홈인테리어'
elif num =='9' :
    num_name='가전_디지털'
elif num =='10' :
    num_name='스포츠_레저'
elif num =='11' :
    num_name='자동차용품'
elif num =='12' :
    num_name='도서_음반_DVD'
elif num =='13' :
    num_name='완구_취미'
elif num =='14' :
    num_name='문구_오피스'
elif num =='15' :
    num_name='반려동물용품'
elif num =='16' :
    num_name='헬스_건강식품'

# 저장될 파일위치와 이름을 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+query_txt+'-'+num_name)
os.chdir(f_dir+s+'-'+query_txt+'-'+num_name)

ff_dir=f_dir+s+'-'+query_txt+'-'+num_name
ff_name=f_dir+s+'-'+query_txt+'-'+num_name+'\\'+s+'-'+query_txt+'-'+num_name+'.txt'
fc_name=f_dir+s+'-'+query_txt+'-'+num_name+'\\'+s+'-'+query_txt+'-'+num_name+'.csv'
fx_name=f_dir+s+'-'+query_txt+'-'+num_name+'\\'+s+'-'+query_txt+'-'+num_name+'.xls'

img_dir = ff_dir+"\\images"
os.makedirs(img_dir)
os.chdir(img_dir)

s_time = time.time( )
driver.find_element_by_xpath("""//*[@id="header"]/div""").click()

if num == '1': #여성패션
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/a""").click()
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/div/div/ul/li[1]/a""").click()
elif num == '2': #남성패션
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/a""").click()
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/div/div/ul/li[2]""").click()
elif num =='3': #뷰티
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[2]""").click()
elif num == '4': #출산.육아등
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[3]""").click()
elif num == '5': #식품
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[4]""").click()
elif num == '6': #주방용품
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[5]""").click()
elif num == '7': #생활용품
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[6]""").click()
elif num == '8': #홈인테리어
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[7]""").click()
elif num == '9': #가전디지털
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[8]""").click()
elif num == '10': #스포츠/레저
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[9]""").click()   
elif num == '11': #자동차용품
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[10]""").click()
elif num == '12': #도서/음반/DVD
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[11]""").click()
elif num == '13': #완구/취미
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[12]""").click()
elif num == '14': #문구/오피스
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[13]""").click()
elif num == '15': #반려동물용품
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[14]""").click()
elif num == '16': #헬스건강식품
    driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[15]""").click()
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_11808/1543368929.py:17: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# 크롤링 하려는 항목 번호를 입력해주세요
# 1.여성패션    2.남성패션        3.뷰티          4.출산.육아등    5.식품
# 6.주방용품    7.생활용품        8.홈인테리어    9.가전디지털    10.스포츠/레저
# 11.자동차용품 12.도서/음반/DVD 13.완구/취미     14.문구/오피스 15.반려동물용품
# 15
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_11808/1543368929.py:31: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath("""//*[@id="header"]/div""").click()
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_11808/1543368929.py:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[14]""").click()
